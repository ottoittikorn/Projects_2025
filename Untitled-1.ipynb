# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sklearn 
import tensorflow as tf 


np.random.seed(42)
url = 'https://static-content.springer.com/esm/art%3A10.1038%2Fs41467-019-08325-8/MediaObjects/41467_2019_8325_MOESM3_ESM.xls'


ram_data = pd.read_excel(url, sheet_name=1)

# %% [markdown]
# Use `type()` to define data structure
# Data Structure is a way in which data are stored for efficient search and retrievlal
#
# Why do you need **Data Structure** ? To organsie workflow
#
#
# - Data can be either mutable or immutable --> changeable or non-changeable
# - Money or name important information should not be changeable

# %%
ram_data.head()
# Out:
#    Catalyst Nr  Nr of publication Cation 1  Cation 1 mol% Cation 2  \
# 0            1                  1       Mn            9.2      NaN
# 1            2                  1       Cd            4.7      NaN
# 2            3                  1       Sn            4.5      NaN
# 3            4                  1       Ti           10.4      NaN
# 4            5                  1       Pt            2.8      NaN
#
#    Cation 2 mol% Cation 3  Cation 3 mol% Cation 4  Cation 4 mol%  ...  \
# 0            NaN      NaN            NaN      NaN            NaN  ...
# 1            NaN      NaN            NaN      NaN            NaN  ...
# 2            NaN      NaN            NaN      NaN            NaN  ...
# 3            NaN      NaN            NaN      NaN            NaN  ...
# 4            NaN      NaN            NaN      NaN            NaN  ...
#
#   p(CH4)/p(O2)  p total, bar Contact time, s  X(O2), % X(CH4), % S(COx), %  \
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
# boston_data = sklearn.datasets.load_boston() 
# data = pd.DataFrame(boston_data.data,
# columns=boston_data.feature_names)
# target = boston_data.target
